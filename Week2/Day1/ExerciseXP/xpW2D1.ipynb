# %%
# Exercise 1

class Cat:
    def __init__(self, cat_name, cat_age):
        self.name = cat_name
        self.age = cat_age

# Instantiate three Cat objects using the code provided above
cat1 = Cat("Pussy", 3)
cat2 = Cat('Tom', 5)
cat3 = Cat('Snow', 8)

def get_age(cat):
    return cat.age
# Outside of the class, create a function that finds the oldest cat and returns the cat
def find_oldest(*cats):
    oldest_cat = max(cats, key = get_age)  #or oldest_cat = max(cats, key = lambda cat: cat.age)
    return oldest_cat

oldest_cat = find_oldest(cat1, cat2, cat3)
print(f'The oldest cat is {oldest_cat.name}, aged {oldest_cat.age}')
# Out:
# The oldest cat is Snow, aged 8

# %%
# Exercise 2
# Create a class called Dog

class Dog:
    def __init__(self, name, height):
        self.name = name
        self.height = height

#  Create a method called bark that prints the following string “<dog_name> goes woof!”
    def bark(self):
        print(f"{self.name} goes woof!")

# dog1 = Dog('Gaz', 72)
# dog1.bark()

# Create a method called jump that prints the following string “<dog_name> jumps <x> cm high!”. x is the height*2
    def jump(self):
        jump_height = self.height * 2
        print(f'{self.name} jumps {jump_height} cm high!')

dog1 = Dog('Gaz', 72)
dog1.bark()
dog1.jump()

# Outside of the class, create an object called davids_dog. His dog’s name is “Rex” and his height is 50cm
davids_dog = Dog("Rex", 50)
print(f"The dog name is {davids_dog.name}, the height is {davids_dog.height}")
davids_dog.bark()
davids_dog.jump()

# Create an object called sarahs_dog. Her dog’s name is “Teacup” and his height is 20cm
sarahs_dog = Dog("Teacup", 20)
print(f"The dog name is {sarahs_dog.name}, the height is {sarahs_dog.height}")
sarahs_dog.bark()
sarahs_dog.jump()

# Create an if statement outside of the class to check which dog is bigger. Print the name of the bigger dog
if davids_dog.height > sarahs_dog.height:
    print("David's dog is higher")
elif davids_dog.height == sarahs_dog.height:
    print("David's dog and Sarah's dog have the same height")
else:
    print("Sarah's dog is higher")
# Out:
# Gaz goes woof!
# Gaz jumps 144 cm high!
# The dog name is Rex, the height is 50
# Rex goes woof!
# Rex jumps 100 cm high!
# The dog name is Teacup, the height is 20
# Teacup goes woof!
# Teacup jumps 40 cm high!
# David's dog is higher

# %%
# Exercise 3
# Define a class called Song, it will show the lyrics of a song.
# Its __init__() method should have two arguments: self and lyrics (a list)

class Song:
    def __init__(self, lyrics):
        self.lyrics = lyrics
        print("A new song has been initialized !")

# Inside your class create a method called sing_me_a_song that prints each element of lyrics on its own line
    def sing_me_a_song(self):
            for line in self.lyrics:  
                print(line)

# Create an object
stairway = Song([
    "There’s a lady who's sure", 
    "all that glitters is gold", 
    "and she’s buying a stairway to heaven"
])

# Call the sing_me_a_song method
stairway.sing_me_a_song()
# Out:
# A new song has been initialized !
# There’s a lady who's sure
# all that glitters is gold
# and she’s buying a stairway to heaven

# %%
# Exercise 4
# Create a class called Zoo
class Zoo:
    def __init__(self, zoo_name):
        self.name = zoo_name
        self.animals = []
        print("A new zoo has been initialized !")

# Create a method called add_animal that takes one parameter new_animal. 
# This method adds the new_animal to the animals list as long as it isn’t already in the list

    def add_animal(self, new_animal):
        if new_animal not in self.animals:
            self.animals.append(new_animal)
            print(f"A new animal - {new_animal} added to the {self.name}")
        else:
            print(f"{new_animal} is already added to the {self.name}.")
            

# Create a method called get_animals that prints all the animals of the zoo
    def get_animals(self):
        for animal in self.animals:
            print(animal)

# Create a method called sell_animal that takes one parameter animal_sold. 
# This method removes the animal from the list and of course the animal needs to exist in the list.

    def sell_animal(self, animal_sold):
        if animal_sold in self.animals:
            self.animals.remove(animal_sold)
            print(f"{animal_sold} has been sold from {self.name}.")
        else:
            print(f"{animal_sold} is not present in {self.name}.")

# Create a method called sort_animals that sorts the animals alphabetically and groups them together
#  based on their first letter

    def sort_animals(self):
        sorted_animals = {}
        for animal in sorted(self.animals):
            first_letter = animal[0].upper()
            if first_letter in sorted_animals:
                sorted_animals[first_letter].append(animal)
            else:
                sorted_animals[first_letter] = [animal]
        return sorted_animals
    
# Create a method called get_groups that prints the animal/animals inside each group
    def get_groups(self):
        sorted_animals = self.sort_animals()
        for k,v in sorted_animals.items():
            print(f"Group {k}: {', '.join(v)}")

# Create a Zoo object called ramat_gan_safari
ramat_gan_safari = Zoo("Ramat Gan Safari")

# Zookeeper adds animals to the zoo
print("Which animal should we add to the zoo? --> Giraffe")
ramat_gan_safari.add_animal("Giraffe")
print("Which animal should we add to the zoo? --> Lion")
ramat_gan_safari.add_animal("Lion")
print("Which animal should we add to the zoo? --> Tiger")
ramat_gan_safari.add_animal("Tiger")
print("Which animal should we add to the zoo? --> Elephant")
ramat_gan_safari.add_animal("Elephant")

# Zookeeper checks all the animals in the zoo
ramat_gan_safari.get_animals()

# Zookeeper sells an animal from the zoo
print("Which animal should we sell from the zoo? --> Lion")
ramat_gan_safari.sell_animal("Lion")

# Zookeeper checks all the animals in the zoo after selling
ramat_gan_safari.get_animals()

# Zookeeper sorts and groups the animals
print("Groups of animals in the zoo:")
ramat_gan_safari.get_groups()
# Out:
# A new zoo has been initialized !
# Which animal should we add to the zoo? --> Giraffe
# A new animal - Giraffe added to the Ramat Gan Safari
# Which animal should we add to the zoo? --> Lion
# A new animal - Lion added to the Ramat Gan Safari
# Which animal should we add to the zoo? --> Tiger
# A new animal - Tiger added to the Ramat Gan Safari
# Which animal should we add to the zoo? --> Elephant
# A new animal - Elephant added to the Ramat Gan Safari
# Giraffe
# Lion
# Tiger
# Elephant
# Which animal should we sell from the zoo? --> Lion
# Lion has been sold from Ramat Gan Safari.
# Giraffe
# Tiger
# Elephant
# Groups of animals in the zoo:
# Group E: Elephant
# Group G: Giraffe
# Group T: Tiger
