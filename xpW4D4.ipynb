# %% [markdown]
# <a href="https://colab.research.google.com/github/EvgeniaKantor/DI-Bootcamp_ML/blob/main/xpW4D4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import numpy as np

# %% [markdown]
# # Data Loading and Exploration

# %% [markdown]
# ## Load the dataset using Pandas. Check for null values and understand data types.

# %%
import pandas as pd

df = pd.read_csv('/content/sample_data/AAPL, 1D 01012007-12072023.csv')

df.head()
# Out:
#          volume    vwap    open   close    high     low        time  \
# 0  1.245445e+09  3.0302  3.0821  2.9929  3.0921  2.9250  1167800400
# 1  8.554834e+08  3.0403  3.0018  3.0593  3.0696  2.9936  1167886800
# 2  8.352580e+08  3.0426  3.0632  3.0375  3.0786  3.0143  1167973200
# 3  7.974138e+08  3.0683  3.0700  3.0525  3.0904  3.0457  1168232400
# 4  3.352007e+09  3.1946  3.0875  3.3061  3.3207  3.0411  1168318800
#
#    transactions
# 0        189737
# 1        136333
# 2        141050
# 3        130547
# 4        569578

# %% [markdown]
# Short descriptions of the columns:
#
# **volume:** Total number of shares or contracts traded during the time period.
#
# **vwap (Volume Weighted Average Price):** Average price of the asset, weighted by volume.
#
# **open:** Opening price of the asset for the time period.
#
# **close:** Closing price of the asset for the time period.
#
# **high:** Highest price reached during the time period.
#
# **low:** Lowest price reached during the time period.
#
# **time:** Timestamp indicating the start of the time period (likely in Unix format).
#
# **transactions:** Number of trades or transactions executed during the time period.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4159 entries, 0 to 4158
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   volume        4159 non-null   float64
#  1   vwap          4159 non-null   float64
#  2   open          4159 non-null   float64
#  3   close         4159 non-null   float64
#  4   high          4159 non-null   float64
#  5   low           4159 non-null   float64
#  6   time          4159 non-null   int64
#  7   transactions  4159 non-null   int64
# dtypes: float64(6), int64(2)
# memory usage: 260.1 KB

# %%
# check null values
print(df.isnull().sum())
# Out:
# volume          0
# vwap            0
# open            0
# close           0
# high            0
# low             0
# time            0
# transactions    0
# dtype: int64

# %%
# Check if all values in the 'transactions' column are unique
is_unique = df['transactions'].nunique() == len(df)
print(is_unique)
# Out:
# False

# %% [markdown]
# ## Examine the time series properties of the data (e.g., frequency, trends).

# %%
# Convert time column to datetime
df['date'] = pd.to_datetime(df['time'], unit='s')

df.head()
# Out:
#          volume    vwap    open   close    high     low        time  \
# 0  1.245445e+09  3.0302  3.0821  2.9929  3.0921  2.9250  1167800400
# 1  8.554834e+08  3.0403  3.0018  3.0593  3.0696  2.9936  1167886800
# 2  8.352580e+08  3.0426  3.0632  3.0375  3.0786  3.0143  1167973200
# 3  7.974138e+08  3.0683  3.0700  3.0525  3.0904  3.0457  1168232400
# 4  3.352007e+09  3.1946  3.0875  3.3061  3.3207  3.0411  1168318800
#
#    transactions                date
# 0        189737 2007-01-03 05:00:00
# 1        136333 2007-01-04 05:00:00
# 2        141050 2007-01-05 05:00:00
# 3        130547 2007-01-08 05:00:00
# 4        569578 2007-01-09 05:00:00

# %%
#drop the column 'time'
df.drop(columns=['time'], inplace=True)
df.head()
# Out:
#          volume    vwap    open   close    high     low  transactions  \
# 0  1.245445e+09  3.0302  3.0821  2.9929  3.0921  2.9250        189737
# 1  8.554834e+08  3.0403  3.0018  3.0593  3.0696  2.9936        136333
# 2  8.352580e+08  3.0426  3.0632  3.0375  3.0786  3.0143        141050
# 3  7.974138e+08  3.0683  3.0700  3.0525  3.0904  3.0457        130547
# 4  3.352007e+09  3.1946  3.0875  3.3061  3.3207  3.0411        569578
#
#                  date
# 0 2007-01-03 05:00:00
# 1 2007-01-04 05:00:00
# 2 2007-01-05 05:00:00
# 3 2007-01-08 05:00:00
# 4 2007-01-09 05:00:00

# %%
#find the differences between dates
time_diff_days = df['date'].diff().dt.days.dropna()

# Plot the frequency of time differences
plt.figure(figsize=(10, 6))
plt.hist(time_diff_days, bins=15, edgecolor='black', alpha=0.7, color='skyblue')
plt.xlabel('Time Difference (days)', fontsize=14)
plt.ylabel('Frequency', fontsize=14)
plt.title('Frequency of Time Differences', fontsize=16)

# Add grid lines and statistics
plt.grid(True, linestyle='--', alpha=0.5)
mean_diff = time_diff_days.mean()
median_diff = time_diff_days.median()
plt.axvline(mean_diff, color='red', linestyle='--', label=f'Mean = {mean_diff:.2f}')
plt.axvline(median_diff, color='green', linestyle='--', label=f'Median = {median_diff:.2f}')
plt.legend()

plt.show()

# %%
# create a new column 'diff_date'
df['diff_date'] = df['date'].diff().dt.days.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4159 entries, 0 to 4158
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   volume        4159 non-null   float64
#  1   vwap          4159 non-null   float64
#  2   open          4159 non-null   float64
#  3   close         4159 non-null   float64
#  4   high          4159 non-null   float64
#  5   low           4159 non-null   float64
#  6   transactions  4159 non-null   int64
#  7   date          4159 non-null   datetime64[ns]
#  8   diff_date     4158 non-null   float64
# dtypes: datetime64[ns](1), float64(7), int64(1)
# memory usage: 292.6 KB

# %%
#Examine trends
#Create a heatmap for all numerical columns accept 'transactions'
num_columns = ['volume', 'vwap', 'diff_date', "open", "close", "high", "low"]

# Create the heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(
    df[num_columns].corr(),
    annot=True,
    cmap='Spectral',
    fmt=".2f",
    linewidths=0.5,
    cbar_kws={"shrink": 0.8}
)
plt.xticks(rotation=45, ha='right', fontsize=12)
plt.yticks(fontsize=12)
plt.title('Correlation Heatmap', fontsize=16)
plt.show()

# %% [markdown]
# It turns out that there is a direct correlation between all indicators except 'volume' (but there is a significant inverse correlation). And there is no correlation between the time interval between transactions and other numerical values

# %% [markdown]
# # Data Visualization

# %% [markdown]
# ## Utilize Matplotlib to plot closing prices and traded volume over time.

# %%
# create a plot for volume over time
plt.figure(figsize=(12, 6))
plt.plot(df['date'], df['volume'], label='Volume', linestyle='-', color='b')
plt.xlabel('Date', fontsize=14)
plt.ylabel('Volume', fontsize=14)
plt.title('Volume Over Time', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Volume Over Time')

# %%
# create a plot for VWAP over time
plt.figure(figsize=(12, 6))
plt.plot(df['date'], df['vwap'], label='VWAP', linestyle='-', color='g')
plt.xlabel('Date', fontsize=14)
plt.ylabel('VWAP', fontsize=14)
plt.title('VWAP Over Time', fontsize=16)
# Out:
# Text(0.5, 1.0, 'VWAP Over Time')

# %%
# create a plot for Closing prices over time
plt.figure(figsize=(12, 6))
plt.plot(df['date'], df['close'], label='Closing Price', linestyle='-', color='r')
plt.xlabel('Date', fontsize=14)
plt.ylabel('Closing Price', fontsize=14)
plt.title('Closing Price Over Time', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Closing Price Over Time')

# %% [markdown]
# ## Create a candlestick chart to depict high and low prices

# %%
# Create a candlestick chart to depict high and low prices
plt.figure(figsize=(12, 6))
plt.plot(df['date'], df['high'], label='High', linestyle='-', color='r')
plt.plot(df['date'], df['low'], label='Low', linestyle='-', color='g')
plt.xlabel('Date', fontsize=14)
plt.ylabel('Price', fontsize=14)
plt.title('High and Low Prices Over Time', fontsize=16)
plt.legend()
plt.grid(True)
plt.show()

# %%
# !pip install mpl_finance
# Out:
# Requirement already satisfied: mpl_finance in /usr/local/lib/python3.11/dist-packages (0.10.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from mpl_finance) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mpl_finance) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mpl_finance) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mpl_finance) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mpl_finance) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mpl_finance) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mpl_finance) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mpl_finance) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mpl_finance) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mpl_finance) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->mpl_finance) (1.17.0)

# %%
from mpl_finance import candlestick_ohlc
import matplotlib.dates as mpl_dates
import datetime
import matplotlib.dates as mdates

# Assuming df is your DataFrame and it's already loaded with the necessary data
# Prepare data for candlestick using OHLC format
ohlc = df[['date', 'open', 'high', 'low', 'close']].copy()
ohlc['date'] = mdates.date2num(pd.to_datetime(ohlc['date']))

# Create the figure and axis for the candlestick chart
fig, ax = plt.subplots(figsize=(15, 7))

# Plot candlestick chart
candlestick_ohlc(ax, ohlc.values, width=0.6, colorup='green', colordown='red', alpha=0.8)

# Set labels and title
ax.set_xlabel('Date')
ax.set_ylabel('Price')
fig.suptitle('Daily Candlestick Chart')

# Format the date on x-axis
date_format = mdates.DateFormatter('%d-%m-%Y')
ax.xaxis.set_major_formatter(date_format)
fig.autofmt_xdate()

# Grid and layout adjustments
ax.grid(True, linestyle='--', alpha=0.5)
fig.tight_layout()

# Display the candlestick chart
plt.show()

# %% [markdown]
# # Statistical Analysis

# %% [markdown]
# ## Compute summary statistics (mean, median, standard deviation) for key columns.

# %%
# Calculate summary statistics for key columns
summary_stats = df[['volume', 'vwap', 'open', 'close', 'high', 'low']].describe().T

# Add median and standard deviation to the summary statistics
summary_stats['median'] = df[['volume', 'vwap', 'open', 'close', 'high', 'low']].median()
summary_stats['std_dev'] = df[['volume', 'vwap', 'open', 'close', 'high', 'low']].std()

# %%
summary_stats
# Out:
#          count          mean           std           min           25%  \
# volume  4159.0  3.662925e+08  3.724793e+08  2.422234e+07  1.067497e+08
# vwap    4159.0  4.639138e+01  5.027756e+01  2.841000e+00  1.193620e+01
# open    4159.0  4.636279e+01  5.023559e+01  2.835400e+00  1.195570e+01
# close   4159.0  4.639606e+01  5.029348e+01  2.792900e+00  1.194715e+01
# high    4159.0  4.688113e+01  5.084387e+01  2.928600e+00  1.202840e+01
# low     4159.0  4.586579e+01  4.968010e+01  2.792900e+00  1.185360e+01
#
#                  50%           75%           max        median       std_dev
# volume  2.136463e+08  4.965321e+08  3.373042e+09  2.136463e+08  3.724793e+08
# vwap    2.588520e+01  5.215415e+01  1.931020e+02  2.588520e+01  5.027756e+01
# open    2.577500e+01  5.226375e+01  1.937800e+02  2.577500e+01  5.023559e+01
# close   2.582500e+01  5.223125e+01  1.939700e+02  2.582500e+01  5.029348e+01
# high    2.626280e+01  5.262625e+01  1.944800e+02  2.626280e+01  5.084387e+01
# low     2.568000e+01  5.179625e+01  1.917600e+02  2.568000e+01  4.968010e+01

# %% [markdown]
# ## Analyze closing prices with a moving average.

# %% [markdown]
# 50-Day Moving Average: Often used to identify short- to medium-term trends.
#
# 200-Day Moving Average: Popular for analyzing long-term trends.

# %%
# Sort by date just in case
df = df.sort_values('date')

# Calculate the moving averages
df['MA_50'] = df['close'].rolling(window=50).mean()   # 50-day moving average
df['MA_200'] = df['close'].rolling(window=200).mean() # 200-day moving average

# Plot closing prices and moving averages
plt.figure(figsize=(15, 7))
plt.plot(df['date'], df['close'], label='Closing Price', color='blue', alpha=0.6)
plt.plot(df['date'], df['MA_50'], label='50-Day MA', color='red', alpha=0.8)
plt.plot(df['date'], df['MA_200'], label='200-Day MA', color='green', alpha=0.8)

# Add labels, title, and legend
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Closing Prices with Moving Averages')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)

# Rotate date labels for better visibility
plt.xticks(rotation=45)

# Display the plot
plt.show()

# %% [markdown]
# # Hypothesis Testing

# %% [markdown]
# ## Execute a t-test to compare average closing prices across different years.

# %%
# Extract the year from the date column
df['year'] = df['date'].dt.year

# Get the unique years in the dataset
years = df['year'].unique()

# Perform t-tests between each pair of years
for i in range(len(years)):
    for j in range(i+1, len(years)):
        year1 = years[i]
        year2 = years[j]

        # Get closing prices for each year
        prices_year1 = df[df['year'] == year1]['close']
        prices_year2 = df[df['year'] == year2]['close']

        # Perform the t-test
        t_stat, p_value = stats.ttest_ind(prices_year1, prices_year2, equal_var=False)

        # Print the result
        print(f"T-test between {year1} and {year2}: t-statistic = {t_stat:.4f}, p-value = {p_value:.4e}")
        alpha = 0.05
        if p_value < alpha:
            print("There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.")
        else:
            print("There is no significant differences in average closing prices across these years.")
# Out:
# T-test between 2007 and 2008: t-statistic = -4.4605, p-value = 1.0104e-05
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2007 and 2009: t-statistic = -5.5304, p-value = 5.1856e-08
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2007 and 2010: t-statistic = -40.5113, p-value = 6.3906e-160
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2007 and 2011: t-statistic = -85.4183, p-value = 5.2687e-284
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2007 and 2012: t-statistic = -93.5858, p-value = 6.1155e-263
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2007 and 2013: t-statistic = -95.7117, p-value = 1.1451e-312
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2007 and 2014: t-statistic = -82.1307, p-value = 1.3991e-217
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2007 and 2015: t-statistic = -175.6656, p-value = 0.0000e+00
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2007 and 2016: t-statistic = -149.5878, p-value = 0.0000e+00
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2007 and 2017: t-statistic = -135.4677, p-value = 7.2265e-277
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2007 and 2018: t-statistic = -127.5845, p-value = 5.8889e-250
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2007 and 2019: t-statistic = -86.3779, p-value = 2.2449e-194
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2007 and 2020: t-statistic = -66.0849, p-value = 6.7937e-162
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2007 and 2021: t-statistic = -147.1690, p-value = 2.0301e-248
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2007 and 2022: t-statistic = -181.4849, p-value = 2.5100e-271
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2007 and 2023: t-statistic = -105.4497, p-value = 2.3675e-128
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2008 and 2009: t-statistic = -1.4706, p-value = 1.4206e-01
# There is no significant differences in average closing prices across these years.
# T-test between 2008 and 2010: t-statistic = -37.0916, p-value = 2.9314e-145
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2008 and 2011: t-statistic = -82.9440, p-value = 8.3955e-284
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2008 and 2012: t-statistic = -91.6275, p-value = 8.0986e-255
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2008 and 2013: t-statistic = -93.5453, p-value = 3.8247e-304
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2008 and 2014: t-statistic = -80.4131, p-value = 5.7448e-212
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2008 and 2015: t-statistic = -174.6979, p-value = 0.0000e+00
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2008 and 2016: t-statistic = -148.2576, p-value = 0.0000e+00
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2008 and 2017: t-statistic = -134.1105, p-value = 4.7828e-272
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2008 and 2018: t-statistic = -126.4463, p-value = 4.4161e-247
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2008 and 2019: t-statistic = -85.5686, p-value = 7.8267e-193
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2008 and 2020: t-statistic = -65.7385, p-value = 2.7848e-161
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2008 and 2021: t-statistic = -146.6898, p-value = 8.2934e-248
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2008 and 2022: t-statistic = -180.9694, p-value = 1.1700e-270
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2008 and 2023: t-statistic = -105.1362, p-value = 3.9070e-128
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2009 and 2010: t-statistic = -32.7825, p-value = 1.1143e-126
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2009 and 2011: t-statistic = -72.5738, p-value = 6.6351e-244
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2009 and 2012: t-statistic = -87.1951, p-value = 1.7439e-264
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2009 and 2013: t-statistic = -86.2063, p-value = 3.0545e-300
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2009 and 2014: t-statistic = -77.8855, p-value = 2.1708e-218
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2009 and 2015: t-statistic = -164.5130, p-value = 0.0000e+00
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2009 and 2016: t-statistic = -139.3797, p-value = 0.0000e+00
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2009 and 2017: t-statistic = -130.8888, p-value = 2.2730e-282
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2009 and 2018: t-statistic = -124.6569, p-value = 1.8391e-252
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2009 and 2019: t-statistic = -84.9335, p-value = 5.0354e-194
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2009 and 2020: t-statistic = -65.5731, p-value = 2.8046e-161
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2009 and 2021: t-statistic = -146.3091, p-value = 1.5596e-248
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2009 and 2022: t-statistic = -180.4602, p-value = 9.2086e-272
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2009 and 2023: t-statistic = -104.9675, p-value = 3.0320e-128
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2010 and 2011: t-statistic = -36.2295, p-value = 6.0963e-135
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2010 and 2012: t-statistic = -65.1693, p-value = 4.6684e-212
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2010 and 2013: t-statistic = -57.7127, p-value = 7.3386e-220
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2010 and 2014: t-statistic = -60.7578, p-value = 3.6273e-181
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2010 and 2015: t-statistic = -140.4548, p-value = 0.0000e+00
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2010 and 2016: t-statistic = -114.7366, p-value = 0.0000e+00
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2010 and 2017: t-statistic = -115.4109, p-value = 2.4053e-260
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2010 and 2018: t-statistic = -113.1206, p-value = 5.0184e-238
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2010 and 2019: t-statistic = -77.7233, p-value = 1.6723e-183
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2010 and 2020: t-statistic = -62.6499, p-value = 1.9266e-156
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2010 and 2021: t-statistic = -142.0309, p-value = 6.7842e-245
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2010 and 2022: t-statistic = -175.7031, p-value = 2.7960e-268
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2010 and 2023: t-statistic = -102.2926, p-value = 1.0188e-126
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2011 and 2012: t-statistic = -46.7072, p-value = 2.5723e-145
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2011 and 2013: t-statistic = -33.2677, p-value = 1.8050e-117
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2011 and 2014: t-statistic = -46.0677, p-value = 3.0768e-135
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2011 and 2015: t-statistic = -126.6314, p-value = 1.2373e-301
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2011 and 2016: t-statistic = -98.3463, p-value = 1.2532e-263
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2011 and 2017: t-statistic = -103.5289, p-value = 2.7026e-226
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2011 and 2018: t-statistic = -103.7774, p-value = 2.8662e-217
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2011 and 2019: t-statistic = -71.4074, p-value = 2.1445e-171
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2011 and 2020: t-statistic = -60.0016, p-value = 1.3722e-151
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2011 and 2021: t-statistic = -138.3205, p-value = 2.1372e-240
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2011 and 2022: t-statistic = -171.6810, p-value = 1.7745e-263
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2011 and 2023: t-statistic = -99.8920, p-value = 4.5608e-125
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2012 and 2013: t-statistic = 20.3050, p-value = 5.9274e-65
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2012 and 2014: t-statistic = -9.6146, p-value = 4.7977e-20
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2012 and 2015: t-statistic = -48.7123, p-value = 4.2174e-187
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2012 and 2016: t-statistic = -28.8549, p-value = 1.6053e-106
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2012 and 2017: t-statistic = -61.8511, p-value = 1.6781e-216
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2012 and 2018: t-statistic = -74.4583, p-value = 4.2413e-218
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2012 and 2019: t-statistic = -55.7769, p-value = 6.1918e-157
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2012 and 2020: t-statistic = -54.2038, p-value = 4.6878e-143
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2012 and 2021: t-statistic = -128.6801, p-value = 1.6223e-240
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2012 and 2022: t-statistic = -160.2430, p-value = 3.0644e-267
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2012 and 2023: t-statistic = -94.4210, p-value = 1.5866e-123
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2013 and 2014: t-statistic = -26.4893, p-value = 1.2819e-86
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2013 and 2015: t-statistic = -83.3089, p-value = 4.5367e-290
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2013 and 2016: t-statistic = -59.0175, p-value = 4.0118e-224
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2013 and 2017: t-statistic = -82.4205, p-value = 6.7274e-228
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2013 and 2018: t-statistic = -89.2850, p-value = 5.0114e-217
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2013 and 2019: t-statistic = -63.5974, p-value = 7.9894e-164
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2013 and 2020: t-statistic = -57.0718, p-value = 3.8498e-147
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2013 and 2021: t-statistic = -133.5984, p-value = 1.7599e-239
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2013 and 2022: t-statistic = -166.1596, p-value = 5.9646e-264
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2013 and 2023: t-statistic = -97.1519, p-value = 4.4032e-124
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2014 and 2015: t-statistic = -28.5911, p-value = 9.2006e-99
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2014 and 2016: t-statistic = -12.7194, p-value = 2.3802e-31
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2014 and 2017: t-statistic = -46.6487, p-value = 1.2214e-183
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2014 and 2018: t-statistic = -62.4880, p-value = 1.7546e-217
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2014 and 2019: t-statistic = -49.7155, p-value = 7.7676e-154
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2014 and 2020: t-statistic = -52.1038, p-value = 6.7375e-141
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2014 and 2021: t-statistic = -124.5001, p-value = 3.3030e-245
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2014 and 2022: t-statistic = -154.9182, p-value = 2.8410e-275
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2014 and 2023: t-statistic = -92.3248, p-value = 5.4145e-124
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2015 and 2016: t-statistic = 22.6134, p-value = 1.3453e-78
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2015 and 2017: t-statistic = -29.2785, p-value = 3.1745e-99
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2015 and 2018: t-statistic = -49.7553, p-value = 4.0873e-152
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2015 and 2019: t-statistic = -39.5776, p-value = 9.7419e-116
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2015 and 2020: t-statistic = -47.4660, p-value = 7.2684e-129
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2015 and 2021: t-statistic = -119.1580, p-value = 1.2058e-228
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2015 and 2022: t-statistic = -149.8629, p-value = 5.3237e-255
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2015 and 2023: t-statistic = -88.3032, p-value = 4.4862e-119
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2016 and 2017: t-statistic = -44.1435, p-value = 5.6846e-151
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2016 and 2018: t-statistic = -60.9249, p-value = 3.5907e-177
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2016 and 2019: t-statistic = -46.5150, p-value = 1.7363e-132
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2016 and 2020: t-statistic = -50.2716, p-value = 1.2845e-134
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2016 and 2021: t-statistic = -123.3129, p-value = 2.2289e-232
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2016 and 2022: t-statistic = -154.5140, p-value = 2.4831e-258
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2016 and 2023: t-statistic = -90.8789, p-value = 1.1136e-120
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2017 and 2018: t-statistic = -24.1520, p-value = 2.5840e-83
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2017 and 2019: t-statistic = -24.4162, p-value = 1.2130e-76
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2017 and 2020: t-statistic = -41.5040, p-value = 2.8769e-118
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2017 and 2021: t-statistic = -108.5791, p-value = 3.2528e-232
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2017 and 2022: t-statistic = -136.9478, p-value = 7.6456e-265
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2017 and 2023: t-statistic = -82.5139, p-value = 3.4952e-118
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2018 and 2019: t-statistic = -7.5765, p-value = 2.3861e-13
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2018 and 2020: t-statistic = -34.1223, p-value = 8.6004e-102
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2018 and 2021: t-statistic = -95.7385, p-value = 1.8758e-233
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2018 and 2022: t-statistic = -121.4331, p-value = 2.0679e-273
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2018 and 2023: t-statistic = -75.2951, p-value = 1.3721e-116
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2019 and 2020: t-statistic = -29.3419, p-value = 6.6435e-94
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2019 and 2021: t-statistic = -82.9715, p-value = 6.4937e-257
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2019 and 2022: t-statistic = -104.0805, p-value = 1.0177e-308
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2019 and 2023: t-statistic = -69.3932, p-value = 4.1580e-124
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2020 and 2021: t-statistic = -27.6095, p-value = 3.3989e-98
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2020 and 2022: t-statistic = -37.1858, p-value = 7.8010e-134
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2020 and 2023: t-statistic = -33.0885, p-value = 9.5405e-106
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2021 and 2022: t-statistic = -11.1866, p-value = 4.7090e-26
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2021 and 2023: t-statistic = -12.2257, p-value = 7.8884e-27
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
# T-test between 2022 and 2023: t-statistic = -4.4749, p-value = 1.2502e-05
# There is a significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.

# %% [markdown]
# **Significant Differences:** Most comparisons show extremely low p-values (e.g., p < 0.05), indicating significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
#
# **Notable Exception:** The comparison between 2008 and 2009 has a p-value of 0.1421, which is above the typical significance level of 0.05. This indicates no statistically significant difference in the average closing prices between these two years, possibly reflecting market stabilization after the 2008 financial crisis.
#
# **Large Negative t-statistics:** The consistently large negative t-statistics imply that the mean closing price in the earlier year was generally lower than in the later year, consistent with a general upward trend in stock prices over the analyzed period.
#
# Magnitude of Change: The magnitude of the t-statistics tends to increase over longer time spans (e.g., 2007 vs. 2022), indicating more pronounced differences in average prices over more extended periods.

# %% [markdown]
# **Significant Differences:** Most comparisons show extremely low p-values (e.g., p < 0.05), indicating significant differences in average closing prices across these years. This suggests that stock prices have experienced substantial shifts over time.
#
# **Notable Exception:** The comparison between 2008 and 2009 has a p-value of 0.1421, which is above the typical significance level of 0.05. This indicates no statistically significant difference in the average closing prices between these two years, possibly reflecting market stabilization after the 2008 financial crisis.
#
# **Large Negative t-statistics:** The consistently large negative t-statistics imply that the mean closing price in the earlier year was generally lower than in the later year, consistent with a general upward trend in stock prices over the analyzed period.
#
# **Magnitude of Change:** The magnitude of the t-statistics tends to increase over longer time spans (e.g., 2007 vs. 2022), indicating more pronounced differences in average prices over more extended periods.

# %% [markdown]
# ## Examine daily returns’ distribution and test for normality using SciPy.

# %%
# Calculate daily returns (adjust this if your data structure is different)
# Assuming 'Close' is the column with daily closing prices
df['daily_returns'] = df['close'].pct_change().dropna()

# Drop NaN values from returns
daily_returns = df['daily_returns'].dropna()

# Visualize Distribution
plt.figure(figsize=(10, 6))
sns.histplot(daily_returns, bins=50, kde=True, color='blue')
plt.title('Histogram of Daily Returns')
plt.xlabel('Daily Returns')
plt.ylabel('Frequency')
plt.show()

# Q-Q Plot
plt.figure(figsize=(8, 8))
stats.probplot(daily_returns, dist="norm", plot=plt)
plt.title('Q-Q Plot of Daily Returns')
plt.show()

# Test for Normality

# Shapiro-Wilk Test
shapiro_stat, shapiro_p = stats.shapiro(daily_returns)
print(f"Shapiro-Wilk Test: W={shapiro_stat:.4f}, p-value={shapiro_p:.4e}")
if shapiro_p > 0.05:
    print("The data appears to be normally distributed.")
else:
    print("The data does not appear to be normally distributed.")
# Out:
# Shapiro-Wilk Test: W=0.9407, p-value=6.1809e-38
# The data does not appear to be normally distributed.

# %% [markdown]
# # Advanced Statistical Techniques (Bonus)

# %%
df.head()
# Out:
#          volume    vwap    open   close    high     low  transactions  \
# 0  1.245445e+09  3.0302  3.0821  2.9929  3.0921  2.9250        189737
# 1  8.554834e+08  3.0403  3.0018  3.0593  3.0696  2.9936        136333
# 2  8.352580e+08  3.0426  3.0632  3.0375  3.0786  3.0143        141050
# 3  7.974138e+08  3.0683  3.0700  3.0525  3.0904  3.0457        130547
# 4  3.352007e+09  3.1946  3.0875  3.3061  3.3207  3.0411        569578
#
#                  date  diff_date  MA_50  MA_200  year  daily_returns
# 0 2007-01-03 05:00:00        NaN    NaN     NaN  2007            NaN
# 1 2007-01-04 05:00:00        1.0    NaN     NaN  2007       0.022186
# 2 2007-01-05 05:00:00        1.0    NaN     NaN  2007      -0.007126
# 3 2007-01-08 05:00:00        3.0    NaN     NaN  2007       0.004938
# 4 2007-01-09 05:00:00        1.0    NaN     NaN  2007       0.083079

# %%
# Define the moving average window size
window_size_50 = 50
window_size_200 = 200

# Calculate Moving Averages using NumPy's convolve
weights_50 = np.ones(window_size_50) / window_size_50
weights_200 = np.ones(window_size_200) / window_size_200

ma_50_np = np.convolve(df['close'], weights_50, mode='valid')
ma_200_np = np.convolve(df['close'], weights_200, mode='valid')

# Pad the moving averages with NaNs to match the length of the DataFrame
ma_50_padded = np.concatenate((np.full(window_size_50 - 1, np.nan), ma_50_np))
ma_200_padded = np.concatenate((np.full(window_size_200 - 1, np.nan), ma_200_np))

# Assign the padded moving averages to the DataFrame using .loc[]
df.loc[:, 'MA_50_np'] = ma_50_padded
df.loc[:, 'MA_200_np'] = ma_200_padded

# %%
df.head()
# Out:
#          volume    vwap    open   close    high     low  transactions  \
# 0  1.245445e+09  3.0302  3.0821  2.9929  3.0921  2.9250        189737
# 1  8.554834e+08  3.0403  3.0018  3.0593  3.0696  2.9936        136333
# 2  8.352580e+08  3.0426  3.0632  3.0375  3.0786  3.0143        141050
# 3  7.974138e+08  3.0683  3.0700  3.0525  3.0904  3.0457        130547
# 4  3.352007e+09  3.1946  3.0875  3.3061  3.3207  3.0411        569578
#
#                  date  diff_date  MA_50  MA_200  year  daily_returns  \
# 0 2007-01-03 05:00:00        NaN    NaN     NaN  2007            NaN
# 1 2007-01-04 05:00:00        1.0    NaN     NaN  2007       0.022186
# 2 2007-01-05 05:00:00        1.0    NaN     NaN  2007      -0.007126
# 3 2007-01-08 05:00:00        3.0    NaN     NaN  2007       0.004938
# 4 2007-01-09 05:00:00        1.0    NaN     NaN  2007       0.083079
#
#    MA_50_np  MA_200_np
# 0       NaN        NaN
# 1       NaN        NaN
# 2       NaN        NaN
# 3       NaN        NaN
# 4       NaN        NaN

# %%
# Drop rows with NaN values for accurate correlation calculation
cleaned_data = df.dropna(subset=['MA_50_np', 'MA_200_np', 'volume'])

# Calculate correlation between MA_50_np and volume
corr_ma50_volume = np.corrcoef(cleaned_data['MA_50_np'], cleaned_data['volume'])[0, 1]

# Calculate correlation between MA_200_np and volume
corr_ma200_volume = np.corrcoef(cleaned_data['MA_200_np'], cleaned_data['volume'])[0, 1]

print(f"Correlation between MA_50_np and Volume: {corr_ma50_volume:.4f}")
print(f"Correlation between MA_200_np and Volume: {corr_ma200_volume:.4f}")
# Out:
# Correlation between MA_50_np and Volume: -0.5072
# Correlation between MA_200_np and Volume: -0.5035

# %% [markdown]
# This indicates a moderate negative correlation, suggesting that as the 50-day and 200-day moving average increases, trading volume tends to decrease, and vice versa.

# %%
cleaned_data.head()
# Out:
#            volume    vwap    open   close    high     low  transactions  \
# 199  1.127612e+09  6.1204  6.1675  6.1696  6.1800  6.0421        206690
# 200  8.242661e+08  6.1698  6.1250  6.1964  6.2211  6.1089        148446
# 201  1.291553e+09  6.1627  6.2229  6.0864  6.2368  6.0714        230652
# 202  1.649497e+09  6.2839  6.0839  6.2271  6.2464  6.0704        295058
# 203  1.794793e+09  6.6436  6.7343  6.6486  6.7357  6.5271        318875
#
#                    date  diff_date     MA_50    MA_200  year  daily_returns  \
# 199 2007-10-17 04:00:00        1.0  5.102888  4.089109  2007       0.018691
# 200 2007-10-18 04:00:00        1.0  5.131102  4.105126  2007       0.004344
# 201 2007-10-19 04:00:00        1.0  5.162552  4.120262  2007      -0.017752
# 202 2007-10-22 04:00:00        3.0  5.197808  4.136210  2007       0.023117
# 203 2007-10-23 04:00:00        1.0  5.239502  4.154190  2007       0.067688
#
#      MA_50_np  MA_200_np
# 199  5.102888   4.089109
# 200  5.131102   4.105126
# 201  5.162552   4.120262
# 202  5.197808   4.136210
# 203  5.239502   4.154191

# %%
# Scatter plot for MA_50_np vs Volume
plt.figure(figsize=(10, 6))
plt.scatter(cleaned_data['MA_50_np'], cleaned_data['volume'], alpha=0.5, color='blue')
plt.title('MA_50_np vs Volume')
plt.xlabel('MA_50_np')
plt.ylabel('Volume')
plt.grid(True)
plt.show()

# Scatter plot for MA_200_np vs Volume
plt.figure(figsize=(10, 6))
plt.scatter(cleaned_data['MA_200_np'], cleaned_data['volume'], alpha=0.5, color='green')
plt.title('MA_200_np vs Volume')
plt.xlabel('MA_200_np')
plt.ylabel('Volume')
plt.grid(True)
plt.show()
