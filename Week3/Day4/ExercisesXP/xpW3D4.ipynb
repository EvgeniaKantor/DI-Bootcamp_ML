# %% [markdown]
# <a href="https://colab.research.google.com/github/EvgeniaKantor/DI-Bootcamp_ML/blob/main/xpW3D4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🌟 Exercise 1: Understanding Data Visualization
#
# Task: Explain why data visualization is important in data analysis. - Data visualization is a crucial part of data analysis because it helps transform raw data into meaningful insights (Enhances Understanding, Identifies Patterns & Trends, Aids Decision-Making, Highlights Outliers,  Improves Communication)
#
# Task: Describe the purpose of a line graph in data visualization. - A line graph is used to display trends and relationships over time

# %% [markdown]
# # 🌟 Exercise 2: Creating a Line Plot for Temperature Variation
#
# Objective: Create a simple line plot using Matplotlib that represents temperature variations over a week.
#
# Tasks:
# Use a list of temperature values for each day of the week (e.g., [72, 74, 76, 80, 82, 78, 75]).
#
# Label the x-axis as “Day” and the y-axis as “Temperature (°F)”.
# Add a title to the plot.
#
# Display the plot.

# %%
import matplotlib.pyplot as plt

tempreture = [72, 74, 76, 80, 82, 78, 75]
days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

plt.plot(days, tempreture)
plt.xlabel('Day of the Week')
plt.ylabel('Temperature (°F)')
plt.title('Temperature Variation Over a Week')
plt.show()

# %% [markdown]
# # 🌟 Exercise 3: Visualizing Monthly Sales with a Bar Chart
#
# Objective: Generate a bar chart using Matplotlib to visualize monthly sales data for a retail store.
#
# Tasks:
# Create a list of sales values for each month (e.g., [5000, 5500, 6200, 7000, 7500]).
#
# Label the x-axis as “Month” and the y-axis as “Sales Amount ($)”.
# Add a title to the bar chart.
#
# Display the plot.

# %%
sales = [5000, 5500, 6200, 7000, 7500]
months = ['January', 'February', 'March', 'April', 'May']
plt.bar(months, sales, color=['red', 'green', 'blue', 'purple', 'pink'], edgecolor='black', hatch='*')
plt.xlabel('Month')
plt.ylabel('Sales Amount ($)')
plt.title('Monthly Retail Store Sales')
plt.show()

# %% [markdown]
# # 🌟 Exercise 4: Visualizing the Distribution of CGPA
#
# Objective: Create a histogram to visualize the distribution of students’ CGPA.
#
# Dataset Overview: Assume the CGPA data is categorized into ranges and loaded in a DataFrame named df.
#
# Tasks:
# Import necessary libraries.
#
# Use Seaborn’s histplot to create a histogram of the CGPA categories.
#
# Customize the histogram with a specific color and add a title.
#
# Display the plot.

# %%
import seaborn as sns
import pandas as pd

# Sample CGPA Data
data = {'CGPA': [2.5, 3.2, 3.8, 3.5, 2.9, 3.1, 3.6, 3.0, 3.9, 2.7, 3.4, 3.3, 3.7, 3.0, 3.2]}
df = pd.DataFrame(data)

sns.histplot(df['CGPA'], bins=5, color='skyblue', kde=True)
plt.title('Distribution of CGPA')
plt.xlabel('CGPA')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # 🌟 Exercise 5: Comparing Anxiety Levels Across Different Genders
#
# Objective: Use a bar plot to compare the proportion of students experiencing anxiety across different genders.
#
# Dataset Overview: The dataset includes columns: ‘Do you have Anxiety?’ and ‘Choose your gender’.
#
# Tasks:
#
# Import necessary libraries.
#
# Use Seaborn to create a bar plot comparing anxiety levels across genders from the dataset df.
#
# Customize the plot with an appropriate color palette and add a title.
#
# Display the plot.

# %%
# The dataset includes columns: ‘Do you have Anxiety?’ and ‘Choose your gender’
data = {'Do you have Anxiety?': ['Yes', 'No', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No'],
        'Gender': ['Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Female', 'Male', 'Female', 'Male']}
df = pd.DataFrame(data)
# Convert categorical data into proportions
anxiety_counts = df.groupby("Gender")["Do you have Anxiety?"].value_counts(normalize=True).unstack()

sns.barplot(x=anxiety_counts.index, y=anxiety_counts["Yes"], hue= anxiety_counts.index, palette="pastel", dodge=False)

# Customize plot
plt.xlabel("Gender", fontsize=12)
plt.ylabel("Proportion with Anxiety", fontsize=12)
plt.title("Anxiety Levels Across Different Genders", fontsize=14)

# Show the plot
plt.show()

# %% [markdown]
# # 🌟 Exercise 6: Exploring the Relationship Between Age and Panic Attacks
#
# Objective: Create a scatter plot to explore the relationship between students’ age and the occurrence of panic attacks.
#
# Dataset Overview: The dataset includes columns: ‘Age’ and ‘Do you have Panic Attacks?’.
#
# Tasks:
#
# Import necessary libraries.
#
# Convert panic attack responses to numeric values (e.g., Yes=1, No=0).
#
# Use Seaborn’s scatterplot to create a scatter plot with ‘Age’ on the x-axis and numeric panic attack responses on the y-axis.
#
# Customize the plot to improve readability by adding labels, a title, and adjusting point styles.
#
# Display the plot.

# %%
from sklearn.preprocessing import LabelEncoder

# The dataset includes columns: ‘Age’ and ‘Do you have Panic Attacks?’
data = {'Age': [18, 29, 30, 41, 52, 63, 74],
        'Do you have Panic Attacks?': ['Yes', 'No', 'Yes', 'Yes', 'Yes', 'No', 'No']}
df = pd.DataFrame(data)

# Convert panic attack responses to numeric values (e.g., Yes=1, No=0)
encoder = LabelEncoder()
df['Panic_Attack_Numeric'] = encoder.fit_transform(df['Do you have Panic Attacks?'])

# Use Seaborn’s scatterplot to create a scatter plot with ‘Age’ on the x-axis and numeric panic attack responses on the y-axis
sns.scatterplot(x='Age', y='Panic_Attack_Numeric', data=df, hue='Do you have Panic Attacks?', palette='coolwarm')
# Customization
plt.xlabel('Age', fontsize=12)
plt.ylabel('Panic Attack (Yes=1, No=0)', fontsize=12)
plt.title('Scatter Plot of Age vs Panic Attacks', fontsize=14)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.grid(True, linestyle='--', alpha=0.6)

# Show plot
plt.show()
